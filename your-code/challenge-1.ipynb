# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries

import pandas as pd
import numpy as np
import math

# %% [markdown]
# #### Import data set.
#
# Read the dataset `pokemon.csv` into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import dataset

pokemon = pd.read_csv('pokemon.csv')

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here

pokemon['Type 1'].unique()

type1 = np.array(pokemon['Type 1'].unique())
type2 = np.array(pokemon['Type 2'].unique())
type = np.append(type1, type2) # Merging two arrays together
type = list(dict.fromkeys(type)) # Converting to a dictionary to remove duplicates (dictionaries need to have unique keys)
type = np.array(type) # converting back to array, as the exercise calls

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# your code here

def mega_clean(x):
    if x.find('Mega') != -1:
        return x[x.find('Mega'):]
    else:
        return x
        
pokemon['Name'] = pokemon['Name'].apply(mega_clean)

# test transformed data
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here

pokemon['A/D Ratio'] = pokemon['Attack']/pokemon['Defense']

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here

pokemon[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].max()]
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True        9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here
pokemon[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].min()]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary  A/D Ratio
# 230      5           2      False   0.043478

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# your code here

def combo_type(row):
    if ((row['Type 1'] != row['Type 1']) == False) & ((row['Type 2'] != row['Type 2']) == False): # when a value is NaN, != comparison (not equal) will return a value "True' as NaNs cannot be compared. For all standard values, the return will always be 'False' - 1 = 1 = True 
            return row['Type 1'] + '-' + row['Type 2']
    elif (row['Type 2'] != row['Type 2']) == True:
            return row['Type 1']        
        
pokemon['Combo Type'] = pokemon.apply(combo_type, axis =1)

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here

pokemon[pokemon['A/D Ratio'] >= pokemon[['A/D Ratio']].sort_values(by = ['A/D Ratio'], ascending = False).iloc[4,0]] 
#take A/D Ratio values, sort descending, take 4th row index (= 5th element) and 0th column index (= 1st column) to obtain a single number for filter clause
# Out:
#        #                  Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 19    15         Mega Beedrill      Bug  Poison    495  65     150       40
# 347  318              Carvanha    Water    Dark    305  45      90       20
# 348  319              Sharpedo    Water    Dark    460  70     120       40
# 428  386    DeoxysNormal Forme  Psychic     NaN    600  50     150       50
# 429  386    DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 453  408              Cranidos     Rock     NaN    350  67     125       40
# 750  681  AegislashBlade Forme    Steel   Ghost    520  60     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio   Combo Type
# 19        15       80    145           1      False      3.750   Bug-Poison
# 347       65       20     65           3      False      4.500   Water-Dark
# 348       95       40     95           3      False      3.000   Water-Dark
# 428      150       50    150           3       True      3.000      Psychic
# 429      180       20    150           3       True      9.000      Psychic
# 453       30       30     58           4      False      3.125         Rock
# 750      150       50     60           6      False      3.000  Steel-Ghost

# %%
#pokemon.sort_values(by = ['A/D Ratio'], ascending=False).head(60) - there is a draw at value 3.0 for the top5
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 429  386       DeoxysAttack Forme   Psychic       NaN    600   50     180
# 347  318                 Carvanha     Water      Dark    305   45      90
# 19    15            Mega Beedrill       Bug    Poison    495   65     150
# 453  408                 Cranidos      Rock       NaN    350   67     125
# 348  319                 Sharpedo     Water      Dark    460   70     120
# 428  386       DeoxysNormal Forme   Psychic       NaN    600   50     150
# 750  681     AegislashBlade Forme     Steel     Ghost    520   60     150
# 454  409                Rampardos      Rock       NaN    495   97     165
# 798  720       HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 186  172                    Pichu  Electric       NaN    205   20      40
# 615  555  DarmanitanStandard Mode      Fire       NaN    480  105     140
# 393  359               Mega Absol      Dark       NaN    565   65     150
# 627  566                   Archen      Rock    Flying    401   55     112
# 478  430                Honchkrow      Dark    Flying    505  100     125
# 61    56                   Mankey  Fighting       NaN    305   40      80
# 114  106                Hitmonlee  Fighting       NaN    455   50     120
# 18    15                 Beedrill       Bug    Poison    395   65      90
# 589  530                Excadrill    Ground     Steel    508  110     135
# 44    39               Jigglypuff    Normal     Fairy    270  115      45
# 359  328                 Trapinch    Ground       NaN    290   45     100
# 317  293                  Whismur    Normal       NaN    240   64      51
# 55    50                  Diglett    Ground       NaN    265   10      55
# 387  354             Mega Banette     Ghost       NaN    555   64     165
# 392  359                    Absol      Dark       NaN    465   65     130
# 147  136                  Flareon      Fire       NaN    525   65     130
# 628  567                 Archeops      Rock    Flying    567   75     140
# 164  150            Mega Mewtwo Y   Psychic       NaN    780  106     150
# 75    69               Bellsprout     Grass    Poison    300   50      75
# 385  353                  Shuppet     Ghost       NaN    295   44      75
# 495  446                 Munchlax    Normal       NaN    390  135      85
# 588  529                  Drilbur    Ground       NaN    328   60      85
# 362  331                   Cacnea     Grass       NaN    335   50      85
# 681  620                 Mienshao  Fighting       NaN    510   65     125
# 611  551                  Sandile    Ground      Dark    292   50      72
# 259  240                    Magby      Fire       NaN    365   45      75
# 213  198                  Murkrow      Dark    Flying    405   60      85
# 279  257            Mega Blaziken      Fire  Fighting    630   80     160
# 188  174                Igglybuff    Normal     Fairy    210   90      30
# 316  292                 Shedinja       Bug     Ghost    236    1      90
# 320  296                 Makuhita  Fighting       NaN    237   72      60
# 315  291                  Ninjask       Bug    Flying    456   61      90
# 321  297                 Hariyama  Fighting       NaN    474  144     120
# 257  238                 Smoochum       Ice   Psychic    305   45      30
# 349  319            Mega Sharpedo     Water      Dark    560   70     140
# 350  320                  Wailmer     Water       NaN    400  130      70
# 26    21                  Spearow    Normal    Flying    262   40      60
# 351  321                  Wailord     Water       NaN    500  170      90
# 246  228                 Houndour      Dark      Fire    330   45      60
# 614  554                 Darumaka      Fire       NaN    315   70      90
# 526  475                  Gallade   Psychic  Fighting    518   68     125
# 367  335                 Zangoose    Normal       NaN    458   73     115
# 363  332                 Cacturne     Grass      Dark    475   70     115
# 448  403                    Shinx  Electric       NaN    263   45      65
# 466  419                 Floatzel     Water       NaN    495   85     105
# 379  347                  Anorith      Rock       Bug    355   45      95
# 163  150            Mega Mewtwo X   Psychic  Fighting    780  106     190
# 559  500                   Emboar      Fire  Fighting    528  110     123
# 91    84                    Doduo    Normal    Flying    310   35      85
# 461  414                   Mothim       Bug    Flying    424   70      94
# 581  522                  Blitzle  Electric       NaN    295   45      60
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  \
# 429       20      180       20    150           3       True   9.000000
# 347       20       65       20     65           3      False   4.500000
# 19        40       15       80    145           1      False   3.750000
# 453       40       30       30     58           4      False   3.125000
# 348       40       95       40     95           3      False   3.000000
# 428       50      150       50    150           3       True   3.000000
# 750       50      150       50     60           6      False   3.000000
# 454       60       65       50     58           4      False   2.750000
# 798       60      170      130     80           6       True   2.666667
# 186       15       35       35     60           2      False   2.666667
# 615       55       30       55     95           5      False   2.545455
# 393       60      115       60    115           3      False   2.500000
# 627       45       74       45     70           5      False   2.488889
# 478       52      105       52     71           4      False   2.403846
# 61        35       35       45     70           1      False   2.285714
# 114       53       35      110     87           1      False   2.264151
# 18        40       45       80     75           1      False   2.250000
# 589       60       50       65     88           5      False   2.250000
# 44        20       45       25     20           1      False   2.250000
# 359       45       45       45     10           3      False   2.222222
# 317       23       51       23     28           3      False   2.217391
# 55        25       35       45     95           1      False   2.200000
# 387       75       93       83     75           3      False   2.200000
# 392       60       75       60     75           3      False   2.166667
# 147       60       95      110     65           1      False   2.166667
# 628       65      112       65    110           5      False   2.153846
# 164       70      194      120    140           1       True   2.142857
# 75        35       70       30     40           1      False   2.142857
# 385       35       63       33     45           3      False   2.142857
# 495       40       40       85      5           4      False   2.125000
# 588       40       30       45     68           5      False   2.125000
# 362       40       85       40     35           3      False   2.125000
# 681       60       95       60    105           5      False   2.083333
# 611       35       35       35     65           5      False   2.057143
# 259       37       70       55     83           2      False   2.027027
# 213       42       85       42     91           2      False   2.023810
# 279       80      130       80    100           3      False   2.000000
# 188       15       40       20     15           2      False   2.000000
# 316       45       30       30     40           3      False   2.000000
# 320       30       20       30     25           3      False   2.000000
# 315       45       50       50    160           3      False   2.000000
# 321       60       40       60     50           3      False   2.000000
# 257       15       85       65     65           2      False   2.000000
# 349       70      110       65    105           3      False   2.000000
# 350       35       70       35     60           3      False   2.000000
# 26        30       31       31     70           1      False   2.000000
# 351       45       90       45     60           3      False   2.000000
# 246       30       80       50     65           2      False   2.000000
# 614       45       15       45     50           5      False   2.000000
# 526       65       65      115     80           4      False   1.923077
# 367       60       60       60     90           3      False   1.916667
# 363       60      115       60     55           3      False   1.916667
# 448       34       40       34     45           4      False   1.911765
# 466       55       85       50    115           4      False   1.909091
# 379       50       40       50     75           3      False   1.900000
# 163      100      154      100    130           1       True   1.900000
# 559       65      100       65     65           5      False   1.892308
# 91        45       35       35     75           1      False   1.888889
# 461       50       94       50     66           4      False   1.880000
# 581       32       50       32     76           5      False   1.875000
#
#            Combo Type
# 429           Psychic
# 347        Water-Dark
# 19         Bug-Poison
# 453              Rock
# 348        Water-Dark
# 428           Psychic
# 750       Steel-Ghost
# 454              Rock
# 798      Psychic-Dark
# 186          Electric
# 615              Fire
# 393              Dark
# 627       Rock-Flying
# 478       Dark-Flying
# 61           Fighting
# 114          Fighting
# 18         Bug-Poison
# 589      Ground-Steel
# 44       Normal-Fairy
# 359            Ground
# 317            Normal
# 55             Ground
# 387             Ghost
# 392              Dark
# 147              Fire
# 628       Rock-Flying
# 164           Psychic
# 75       Grass-Poison
# 385             Ghost
# 495            Normal
# 588            Ground
# 362             Grass
# 681          Fighting
# 611       Ground-Dark
# 259              Fire
# 213       Dark-Flying
# 279     Fire-Fighting
# 188      Normal-Fairy
# 316         Bug-Ghost
# 320          Fighting
# 315        Bug-Flying
# 321          Fighting
# 257       Ice-Psychic
# 349        Water-Dark
# 350             Water
# 26      Normal-Flying
# 351             Water
# 246         Dark-Fire
# 614              Fire
# 526  Psychic-Fighting
# 367            Normal
# 363        Grass-Dark
# 448          Electric
# 466             Water
# 379          Rock-Bug
# 163  Psychic-Fighting
# 559     Fire-Fighting
# 91      Normal-Flying
# 461        Bug-Flying
# 581          Electric

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here
top5_cat = pokemon['Combo Type'][pokemon['A/D Ratio'] >= pokemon[['A/D Ratio']].sort_values(by = ['A/D Ratio'], ascending = False).iloc[4,0]].unique().tolist()
top5_cat
# I am also getting another category - Steel-Ghost in my results
# Out:
# ['Bug-Poison', 'Water-Dark', 'Psychic', 'Rock', 'Steel-Ghost']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here

pokemon[pokemon['Combo Type'].isin(top5_cat)].groupby(['Combo Type'])['#', 'Total','HP','Attack','Defense','Sp. Atk','Sp. Def', 'Speed', 'Generation', 'Legendary', 'A/D Ratio'].agg(np.average)

# I am also getting another category - Steel-Ghost, which has the same A/D ratio as other top5 pokemons
# Out:
# <ipython-input-20-dab3904f5f6d>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pokemon[pokemon['Combo Type'].isin(top5_cat)].groupby(['Combo Type'])['#', 'Total','HP','Attack','Defense','Sp. Atk','Sp. Def', 'Speed', 'Generation', 'Legendary', 'A/D Ratio'].agg(np.average)
#                       #       Total         HP      Attack     Defense  \
# Combo Type
# Bug-Poison   199.166667  347.916667  53.750000   68.333333   58.083333
# Psychic      381.973684  464.552632  72.552632   64.947368   67.236842
# Rock         410.111111  409.444444  67.111111  103.333333  107.222222
# Steel-Ghost  680.250000  453.250000  56.000000   97.500000  112.500000
# Water-Dark   347.666667  493.833333  69.166667  120.000000   65.166667
#
#                Sp. Atk    Sp. Def      Speed  Generation  Legendary  A/D Ratio
# Combo Type
# Bug-Poison   42.500000  59.333333  65.916667    2.333333   0.000000   1.315989
# Psychic      98.552632  82.394737  78.868421    3.342105   0.236842   1.164196
# Rock         40.555556  58.333333  32.888889    3.888889   0.111111   1.260091
# Steel-Ghost  70.000000  71.500000  45.750000    6.000000   0.000000   1.216667
# Water-Dark   88.833333  63.500000  87.166667    3.166667   0.000000   2.291949
